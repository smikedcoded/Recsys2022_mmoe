# %% [markdown]
# #Config

# %%
config={
    'embedding_dim':64,
    'lr':0.001,
    'batch_size':256,
    'Epoch':5,
    'max_length':20,
    'device':torch.device('cuda'),
    'K':4,
    'n_items':15406,
    'train_path':'../'
}
